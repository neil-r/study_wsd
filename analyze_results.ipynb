# %%
import sqlite3
import pandas as pd


database_path = "./data.db"

# %%
with sqlite3.connect(database_path) as db_c:
    df_results = pd.read_sql_query("SELECT * FROM wsd_results",con=db_c)

# %%
df_results.shape
# Out:
# (19, 9)

# %%
df_results
# Out:
#                                         evaluation_id  \
# 0   365dc7de6c08fd467c781b79c7f28e249578b3d986bc15...
# 1   ca23f9833bc5449b2bf63f168482c67815b655d4d9acb0...
# 2   a06b36b524909984f0c54613783698172d4fcb5108cb00...
# 3   267040a0edcc5a7f4a555cbaa1f8f0d83d8b1cdffb5584...
# 4   24cf84eb54aeae24f1c50fefed68f5f3407e2640824ff2...
# 5   751cb35ceeb8202b3dc4eefe94185c6fa24ad9bc73ce9a...
# 6   da05787b9f0879e27791838fe040b332b0db4fd3f0dcab...
# 7   559f495b8c2077b6205e4ff352295015bbe54c30be1a73...
# 8   c7a8663a23a9cbf24420adf5c90b4b2df1f9d010b45f68...
# 9   55abba1f8ca35a45e9949257b678f25012c1b6c8a0746e...
# 10  097618868d90136be5275015cd581ac96315c3ff371e8d...
# 11  b9ee22ccd93aefed528c9fffbf75e0f3a9a3402829d108...
# 12  2b34d7f6069b0abe94ca9ed41255533e8dbacdd9a72464...
# 13  1d91fbdb55f0330c37329d73cbb06326eeda3171d865c0...
# 14  69ebee119eeac8695422b0d24a429e28474095142ed78e...
# 15  fd38313a676e897bb8322e0bf8b6d5f37c74d4719252c1...
# ...
