# %%
import sqlite3
import pandas as pd


database_path = "./data.db"

# %%
with sqlite3.connect(database_path) as db_c:
    df_results = pd.read_sql_query("SELECT * FROM wsd_results",con=db_c)

# %%
df_results.head()
# Out:
#                                        evaluation_id  \
# 0  bdde33c417947839ddcf193363bc676b2912057cedb489...
# 1  d00fb2dd5e8a1f27d43a03695a648939d01e662c1643fe...
# 2  198a377c432606891b1d4746efaa59f87df61e2ba87b72...
# 3  968249acd2dc8fe7c2fdec90c30b30e92ae34fb2f07a02...
# 4  796c372284617986124874a44d10f7430d9ecb82703dd1...
#
#                                            evalution  \
# 0  {"answer": "friday.n.01", "options": ["friday....
# 1  {"answer": "probe.n.01", "options": ["probe.n....
# 2  {"answer": "atlanta.n.01", "options": ["atlant...
# 3  {"answer": "primary.n.01", "options": ["primar...
# 4  {"answer": "evidence.n.01", "options": ["evide...
#
#                                                  log  discussion_duration  \
# 0  [{"role": "user", "content": "Question:\nWhat ...             0.000064
# 1  [{"role": "user", "content": "Question:\nWhat ...             0.000014
# 2  [{"role": "user", "content": "Question:\nWhat ...             0.000014
# 3  [{"role": "user", "content": "Question:\nWhat ...             0.000012
# 4  [{"role": "user", "content": "Question:\nWhat ...             0.000011
#
#     prompt_strategy answer_value answer_response  correct
# 0  DefaultWsePrompt            A               A        1
# 1  DefaultWsePrompt            A               A        1
# 2  DefaultWsePrompt            A               A        1
# 3  DefaultWsePrompt            A               A        1
# 4  DefaultWsePrompt            A               A        1
